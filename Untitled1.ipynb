# %% [markdown]
# <a href="https://colab.research.google.com/github/Aayush21037/aiml_bootcamp_2026/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = [
    {"name":"Aayush","Attendance":78.98,"Marks":79,"Lab_assignment":True},
    {"name":"Rahul","Attendance":68.98,"Marks":40,"Lab_assignment":False},
    {"name":"Utkarsh","Attendance":67.98,"Marks":30,"Lab_assignment":False},
    {"name":"Pranav","Attendance":75.98,"Marks":74,"Lab_assignment":True},
    {"name":"Ram","Attendance":88.98,"Marks":52,"Lab_assignment":True},
]
print("According to marks : ")
for student in students:
  if student["Marks"]>40:
    print(student['name']+" - Pass")
  else:
    print(student['name']+" - Fail")
print()
print("According to Attendance : ")
for student in students:
  if student['Attendance']>=75:
    print(student['name']+" - Elligible")
  else:
    print(student['name']+" - Not elligible")
# Out:
# According to marks :
# Aayush - Pass
# Rahul - Fail
# Utkarsh - Fail
# Pranav - Pass
# Ram - Pass
#
# According to Attendance :
# Aayush - Elligible
# Rahul - Not elligible
# Utkarsh - Not elligible
# Pranav - Elligible
# Ram - Elligible
